# %%
# !pip install --upgrade torch torchvision opencv-python matplotlib
# !apt-get install ffmpeg -y > /dev/null 2>&1
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting torch
#   Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.7 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 MB 4.1 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 112.9 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 34.9 MB/s eta 0:00:00
# Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 122.2 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.6.0.74
#     Uninstalling nvidia-cudnn-cu12-9.6.0.74:
#       Successfully uninstalled nvidia-cudnn-cu12-9.6.0.74
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# Successfully installed matplotlib-3.10.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencv-python-4.11.0.86 torch-2.6.0 torchvision-0.21.0 triton-3.2.0

# %%
# Model file
model_path = "/content/faster_rcnn_checkpoint_epoch_86.pth"

# Input paths
image_input_path = "/content/test_images"
mp4_video_path = "/content/video1.mp4"
#webm_video_path = "/content/video2.webm"

# Confidence threshold
threshold = 0.05

# %%
# 🚀 Install dependencies (Ensure latest torchvision version)
# !pip install --upgrade torch torchvision opencv-python matplotlib
# !apt-get install ffmpeg -y > /dev/null 2>&1

import torch
import torchvision.transforms as T
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor  # Fixed import issue
import cv2
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# ✅ Define class names (Modify if needed)
CLASS_NAMES = {
    0: "Booken piece", 1: "Conglomerate", 2:"XL", 3:"Empty", 4:"Fissile shale",
    5: "LA", 6:"Non-core", 7: "Rip-up", 8:"SSD", 9: "Wavy bedding",
    10:"BMM", 11: "BSM", 12: "Concretion", 13:"Current ripple",
    14: "Intraclast", 15: "MM", 16:"MS", 17: "MD", 18: "PL"
}  # Update if needed

# ✅ Load Faster R-CNN model
def load_model(model_path, device, num_classes=19):
    model = fasterrcnn_resnet50_fpn(weights=None, num_classes=num_classes)
    state_dict = torch.load(model_path, map_location=device)

    if "model_state_dict" in state_dict:
        print("⚠️ Warning: Model file contains extra keys! Loading only 'model_state_dict'.")
        state_dict = state_dict["model_state_dict"]

    model.load_state_dict(state_dict, strict=False)  # Allow extra keys
    model.to(device)
    model.eval()
    return model

# ✅ Preprocess image for model inference
def preprocess_image(image):
    transform = T.Compose([T.ToTensor()])
    return transform(image).unsqueeze(0)

# ✅ Inference function (Detect objects)
def inference(model, image_tensor, device, threshold=0.2):
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        predictions = model(image_tensor)

    pred_boxes = predictions[0]['boxes'].cpu().numpy()
    pred_scores = predictions[0]['scores'].cpu().numpy()
    pred_labels = predictions[0]['labels'].cpu().numpy()

    # Filter predictions based on confidence threshold
    filtered_boxes = [box for i, box in enumerate(pred_boxes) if pred_scores[i] > threshold]
    filtered_scores = [score for score in pred_scores if score > threshold]
    filtered_labels = [label for i, label in enumerate(pred_labels) if pred_scores[i] > threshold]

    return filtered_boxes, filtered_scores, filtered_labels

# ✅ Visualize results (For images)
def visualize_results(image, boxes, scores, labels, save_path=None):
    fig, ax = plt.subplots(1, figsize=(12, 8))
    ax.imshow(image)

    for box, score, label in zip(boxes, scores, labels):
        x_min, y_min, x_max, y_max = box
        rect = patches.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                                 linewidth=2, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
        class_name = CLASS_NAMES.get(label, "Unknown")
        ax.text(x_min, y_min - 5, f"{class_name}, Score: {score:.2f}",
                color='red', fontsize=10, bbox=dict(facecolor='white', alpha=0.5))

    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        print(f"✅ Image saved: {save_path}")

    plt.close(fig)

# ✅ Process images
def process_images(folder_path, model, device, threshold):
    output_folder = "output_images"
    os.makedirs(output_folder, exist_ok=True)

    for image_name in os.listdir(folder_path):
        if image_name.lower().endswith((".jpg", ".png", ".jpeg")):
            image_path = os.path.join(folder_path, image_name)
            image = Image.open(image_path).convert("RGB")
            image_tensor = preprocess_image(image)
            boxes, scores, labels = inference(model, image_tensor, device, threshold)

            output_image_path = os.path.join(output_folder, f"detected_{image_name}")
            visualize_results(image, boxes, scores, labels, save_path=output_image_path)

# ✅ Process video
def process_video(video_path, model, device, threshold):
    cap = cv2.VideoCapture(video_path, cv2.CAP_FFMPEG)  # Force FFmpeg for better compatibility
    if not cap.isOpened():
        print("❌ Error: Cannot open video. Try converting it to .mp4 using ffmpeg.")
        return

    output_folder = "output_videos"
    os.makedirs(output_folder, exist_ok=True)

    output_video_path = os.path.join(output_folder, os.path.basename(video_path).replace(".webm", "_detected.webm").replace(".mp4", "_detected.mp4"))
    fourcc = cv2.VideoWriter_fourcc(*"VP80") if video_path.lower().endswith(".webm") else cv2.VideoWriter_fourcc(*"mp4v")
    width, height = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    frame_count = 0
    total_detections = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        image_tensor = preprocess_image(image)
        boxes, scores, labels = inference(model, image_tensor, device, threshold)

        frame_detections = len(boxes)
        total_detections += frame_detections
        print(f"🔎 Frame {frame_count}: {frame_detections} objects detected")

        for box, score, label in zip(boxes, scores, labels):
            x_min, y_min, x_max, y_max = [int(i) for i in box]
            cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
            class_name = CLASS_NAMES.get(label, "Unknown")
            cv2.putText(frame, f"{class_name}, {score:.2f}", (x_min, y_min - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        out.write(frame)
        frame_count += 1

    cap.release()
    out.release()

    if total_detections > 0:
        print(f"✅ Processed video saved: {output_video_path} with {total_detections} detections.")
    else:
        print("⚠️ No objects detected. Try lowering the confidence threshold.")

# ✅ Main function
def main(input_path, model_path, threshold=0.2):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"🚀 Using device: {device}")

    model = load_model(model_path, device)

    if input_path.lower().endswith((".mp4", ".avi", ".mov", ".webm")):
        process_video(input_path, model, device, threshold)
    else:
        process_images(input_path, model, device, threshold)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.10/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
main(image_input_path, model_path, threshold)
# Out:
# 🚀 Using device: cuda
# ⚠️ Warning: Model file contains extra keys! Loading only 'model_state_dict'.
# ✅ Image saved: output_images/detected_image7.jpg
# ✅ Image saved: output_images/detected_image8.jpg
# ✅ Image saved: output_images/detected_image10.jpg
# ✅ Image saved: output_images/detected_image6.jpg
# ✅ Image saved: output_images/detected_image9.jpg
# ✅ Image saved: output_images/detected_image2.jpg
# ✅ Image saved: output_images/detected_image5.jpg
# ✅ Image saved: output_images/detected_image3.jpg
# ✅ Image saved: output_images/detected_image4.jpg
# ✅ Image saved: output_images/detected_image1.jpg

# %%
main(mp4_video_path, model_path, threshold)
# Out:
# 🚀 Using device: cuda
# ⚠️ Warning: Model file contains extra keys! Loading only 'model_state_dict'.
# 🔎 Frame 0: 80 objects detected
# 🔎 Frame 1: 78 objects detected
# 🔎 Frame 2: 78 objects detected
# 🔎 Frame 3: 78 objects detected
# 🔎 Frame 4: 82 objects detected
# 🔎 Frame 5: 82 objects detected
# 🔎 Frame 6: 80 objects detected
# 🔎 Frame 7: 83 objects detected
# 🔎 Frame 8: 82 objects detected
# 🔎 Frame 9: 80 objects detected
# 🔎 Frame 10: 80 objects detected
# 🔎 Frame 11: 79 objects detected
# 🔎 Frame 12: 81 objects detected
# 🔎 Frame 13: 81 objects detected
# 🔎 Frame 14: 80 objects detected
# 🔎 Frame 15: 81 objects detected
# 🔎 Frame 16: 80 objects detected
# 🔎 Frame 17: 81 objects detected
# 🔎 Frame 18: 80 objects detected
# 🔎 Frame 19: 80 objects detected
# 🔎 Frame 20: 80 objects detected
# 🔎 Frame 21: 80 objects detected
# 🔎 Frame 22: 80 objects detected
# 🔎 Frame 23: 80 objects detected
# 🔎 Frame 24: 80 objects detected
# 🔎 Frame 25: 80 objects detected
# 🔎 Frame 26: 80 objects detected
# 🔎 Frame 27: 80 objects detected
# 🔎 Frame 28: 80 objects detected
# 🔎 Frame 29: 79 objects detected
# 🔎 Frame 30: 80 objects detected
# 🔎 Frame 31: 79 objects detected
# 🔎 Frame 32: 80 objects detected
# 🔎 Frame 33: 80 objects detected
# 🔎 Frame 34: 80 objects detected
# 🔎 Frame 35: 80 objects detected
# 🔎 Frame 36: 81 objects detected
# 🔎 Frame 37: 80 objects detected
# 🔎 Frame 38: 80 objects detected
# 🔎 Frame 39: 80 objects detected
# 🔎 Frame 40: 80 objects detected
# 🔎 Frame 41: 80 objects detected
# 🔎 Frame 42: 80 objects detected
# 🔎 Frame 43: 80 objects detected
# 🔎 Frame 44: 81 objects detected
# 🔎 Frame 45: 80 objects detected
# 🔎 Frame 46: 80 objects detected
# 🔎 Frame 47: 80 objects detected
# 🔎 Frame 48: 80 objects detected
# 🔎 Frame 49: 81 objects detected
# 🔎 Frame 50: 81 objects detected
# 🔎 Frame 51: 81 objects detected
# 🔎 Frame 52: 81 objects detected
# 🔎 Frame 53: 81 objects detected
# 🔎 Frame 54: 81 objects detected
# 🔎 Frame 55: 81 objects detected
# 🔎 Frame 56: 81 objects detected
# 🔎 Frame 57: 81 objects detected
# 🔎 Frame 58: 81 objects detected
# 🔎 Frame 59: 81 objects detected
# 🔎 Frame 60: 81 objects detected
# 🔎 Frame 61: 79 objects detected
# 🔎 Frame 62: 80 objects detected
# 🔎 Frame 63: 80 objects detected
# 🔎 Frame 64: 81 objects detected
# 🔎 Frame 65: 80 objects detected
# 🔎 Frame 66: 80 objects detected
# 🔎 Frame 67: 80 objects detected
# 🔎 Frame 68: 81 objects detected
# 🔎 Frame 69: 80 objects detected
# 🔎 Frame 70: 80 objects detected
# 🔎 Frame 71: 80 objects detected
# 🔎 Frame 72: 80 objects detected
# 🔎 Frame 73: 80 objects detected
# 🔎 Frame 74: 80 objects detected
# 🔎 Frame 75: 80 objects detected
# 🔎 Frame 76: 80 objects detected
# 🔎 Frame 77: 80 objects detected
# 🔎 Frame 78: 80 objects detected
# 🔎 Frame 79: 80 objects detected
# 🔎 Frame 80: 80 objects detected
# 🔎 Frame 81: 80 objects detected
# 🔎 Frame 82: 81 objects detected
# 🔎 Frame 83: 81 objects detected
# 🔎 Frame 84: 60 objects detected
# 🔎 Frame 85: 59 objects detected
# 🔎 Frame 86: 99 objects detected
# 🔎 Frame 87: 100 objects detected
# 🔎 Frame 88: 100 objects detected
# 🔎 Frame 89: 97 objects detected
# 🔎 Frame 90: 100 objects detected
# 🔎 Frame 91: 100 objects detected
# 🔎 Frame 92: 100 objects detected
# 🔎 Frame 93: 100 objects detected
# 🔎 Frame 94: 100 objects detected
# 🔎 Frame 95: 100 objects detected
# 🔎 Frame 96: 100 objects detected
# 🔎 Frame 97: 100 objects detected
# 🔎 Frame 98: 100 objects detected
# 🔎 Frame 99: 100 objects detected
# 🔎 Frame 100: 100 objects detected
# 🔎 Frame 101: 100 objects detected
# 🔎 Frame 102: 100 objects detected
# 🔎 Frame 103: 100 objects detected
# 🔎 Frame 104: 100 objects detected
# 🔎 Frame 105: 100 objects detected
# 🔎 Frame 106: 100 objects detected
# 🔎 Frame 107: 100 objects detected
# 🔎 Frame 108: 100 objects detected
# 🔎 Frame 109: 100 objects detected
# 🔎 Frame 110: 100 objects detected
# 🔎 Frame 111: 100 objects detected
# 🔎 Frame 112: 100 objects detected
# 🔎 Frame 113: 100 objects detected
# 🔎 Frame 114: 100 objects detected
# 🔎 Frame 115: 100 objects detected
# 🔎 Frame 116: 100 objects detected
# 🔎 Frame 117: 100 objects detected
# 🔎 Frame 118: 100 objects detected
# 🔎 Frame 119: 100 objects detected
# 🔎 Frame 120: 100 objects detected
# 🔎 Frame 121: 100 objects detected
# 🔎 Frame 122: 100 objects detected
# 🔎 Frame 123: 100 objects detected
# 🔎 Frame 124: 100 objects detected
# 🔎 Frame 125: 100 objects detected
# 🔎 Frame 126: 100 objects detected
# 🔎 Frame 127: 100 objects detected
# 🔎 Frame 128: 100 objects detected
# 🔎 Frame 129: 100 objects detected
# 🔎 Frame 130: 100 objects detected
# 🔎 Frame 131: 100 objects detected
# 🔎 Frame 132: 100 objects detected
# 🔎 Frame 133: 100 objects detected
# 🔎 Frame 134: 100 objects detected
# 🔎 Frame 135: 100 objects detected
# 🔎 Frame 136: 100 objects detected
# 🔎 Frame 137: 100 objects detected
# 🔎 Frame 138: 100 objects detected
# 🔎 Frame 139: 100 objects detected
# 🔎 Frame 140: 100 objects detected
# 🔎 Frame 141: 100 objects detected
# 🔎 Frame 142: 100 objects detected
# 🔎 Frame 143: 100 objects detected
# 🔎 Frame 144: 100 objects detected
# 🔎 Frame 145: 100 objects detected
# 🔎 Frame 146: 100 objects detected
# 🔎 Frame 147: 100 objects detected
# 🔎 Frame 148: 100 objects detected
# 🔎 Frame 149: 100 objects detected
# 🔎 Frame 150: 100 objects detected
# 🔎 Frame 151: 100 objects detected
# 🔎 Frame 152: 100 objects detected
# 🔎 Frame 153: 100 objects detected
# 🔎 Frame 154: 100 objects detected
# 🔎 Frame 155: 100 objects detected
# 🔎 Frame 156: 100 objects detected
# 🔎 Frame 157: 100 objects detected
# 🔎 Frame 158: 100 objects detected
# 🔎 Frame 159: 100 objects detected
# 🔎 Frame 160: 100 objects detected
# 🔎 Frame 161: 100 objects detected
# 🔎 Frame 162: 100 objects detected
# 🔎 Frame 163: 100 objects detected
# 🔎 Frame 164: 100 objects detected
# 🔎 Frame 165: 100 objects detected
# 🔎 Frame 166: 100 objects detected
# 🔎 Frame 167: 100 objects detected
# 🔎 Frame 168: 100 objects detected
# 🔎 Frame 169: 100 objects detected
# 🔎 Frame 170: 100 objects detected
# 🔎 Frame 171: 100 objects detected
# 🔎 Frame 172: 100 objects detected
# 🔎 Frame 173: 100 objects detected
# 🔎 Frame 174: 100 objects detected
# 🔎 Frame 175: 100 objects detected
# 🔎 Frame 176: 100 objects detected
# 🔎 Frame 177: 100 objects detected
# 🔎 Frame 178: 100 objects detected
# 🔎 Frame 179: 100 objects detected
# 🔎 Frame 180: 100 objects detected
# 🔎 Frame 181: 100 objects detected
# 🔎 Frame 182: 100 objects detected
# 🔎 Frame 183: 100 objects detected
# 🔎 Frame 184: 100 objects detected
# 🔎 Frame 185: 100 objects detected
# 🔎 Frame 186: 100 objects detected
# 🔎 Frame 187: 100 objects detected
# 🔎 Frame 188: 100 objects detected
# 🔎 Frame 189: 100 objects detected
# 🔎 Frame 190: 100 objects detected
# 🔎 Frame 191: 100 objects detected
# 🔎 Frame 192: 100 objects detected
# 🔎 Frame 193: 100 objects detected
# 🔎 Frame 194: 100 objects detected
# 🔎 Frame 195: 100 objects detected
# 🔎 Frame 196: 100 objects detected
# 🔎 Frame 197: 100 objects detected
# 🔎 Frame 198: 100 objects detected
# 🔎 Frame 199: 100 objects detected
# 🔎 Frame 200: 100 objects detected
# 🔎 Frame 201: 100 objects detected
# 🔎 Frame 202: 100 objects detected
# 🔎 Frame 203: 100 objects detected
# 🔎 Frame 204: 100 objects detected
# 🔎 Frame 205: 100 objects detected
# 🔎 Frame 206: 100 objects detected
# 🔎 Frame 207: 100 objects detected
# 🔎 Frame 208: 100 objects detected
# 🔎 Frame 209: 100 objects detected
# 🔎 Frame 210: 100 objects detected
# 🔎 Frame 211: 100 objects detected
# 🔎 Frame 212: 100 objects detected
# 🔎 Frame 213: 100 objects detected
# 🔎 Frame 214: 100 objects detected
# 🔎 Frame 215: 100 objects detected
# 🔎 Frame 216: 100 objects detected
# 🔎 Frame 217: 100 objects detected
# 🔎 Frame 218: 100 objects detected
# 🔎 Frame 219: 100 objects detected
# 🔎 Frame 220: 100 objects detected
# 🔎 Frame 221: 100 objects detected
# 🔎 Frame 222: 100 objects detected
# 🔎 Frame 223: 100 objects detected
# 🔎 Frame 224: 100 objects detected
# 🔎 Frame 225: 100 objects detected
# 🔎 Frame 226: 100 objects detected
# 🔎 Frame 227: 100 objects detected
# 🔎 Frame 228: 100 objects detected
# 🔎 Frame 229: 100 objects detected
# 🔎 Frame 230: 100 objects detected
# 🔎 Frame 231: 100 objects detected
# 🔎 Frame 232: 100 objects detected
# 🔎 Frame 233: 100 objects detected
# 🔎 Frame 234: 100 objects detected
# 🔎 Frame 235: 100 objects detected
# 🔎 Frame 236: 100 objects detected
# 🔎 Frame 237: 100 objects detected
# 🔎 Frame 238: 100 objects detected
# 🔎 Frame 239: 100 objects detected
# 🔎 Frame 240: 100 objects detected
# 🔎 Frame 241: 100 objects detected
# 🔎 Frame 242: 100 objects detected
# 🔎 Frame 243: 100 objects detected
# 🔎 Frame 244: 100 objects detected
# 🔎 Frame 245: 100 objects detected
# 🔎 Frame 246: 100 objects detected
# 🔎 Frame 247: 100 objects detected
# 🔎 Frame 248: 100 objects detected
# 🔎 Frame 249: 100 objects detected
# 🔎 Frame 250: 100 objects detected
# 🔎 Frame 251: 100 objects detected
# 🔎 Frame 252: 100 objects detected
# 🔎 Frame 253: 100 objects detected
# 🔎 Frame 254: 100 objects detected
# 🔎 Frame 255: 100 objects detected
# 🔎 Frame 256: 100 objects detected
# 🔎 Frame 257: 100 objects detected
# 🔎 Frame 258: 100 objects detected
# 🔎 Frame 259: 100 objects detected
# 🔎 Frame 260: 100 objects detected
# 🔎 Frame 261: 100 objects detected
# 🔎 Frame 262: 100 objects detected
# 🔎 Frame 263: 100 objects detected
# 🔎 Frame 264: 100 objects detected
# 🔎 Frame 265: 100 objects detected
# 🔎 Frame 266: 100 objects detected
# 🔎 Frame 267: 100 objects detected
# 🔎 Frame 268: 100 objects detected
# 🔎 Frame 269: 100 objects detected
# 🔎 Frame 270: 100 objects detected
# 🔎 Frame 271: 100 objects detected
# 🔎 Frame 272: 100 objects detected
# 🔎 Frame 273: 100 objects detected
# 🔎 Frame 274: 100 objects detected
# 🔎 Frame 275: 100 objects detected
# 🔎 Frame 276: 100 objects detected
# 🔎 Frame 277: 100 objects detected
# 🔎 Frame 278: 100 objects detected
# 🔎 Frame 279: 100 objects detected
# 🔎 Frame 280: 100 objects detected
# 🔎 Frame 281: 100 objects detected
# 🔎 Frame 282: 100 objects detected
# 🔎 Frame 283: 100 objects detected
# 🔎 Frame 284: 100 objects detected
# 🔎 Frame 285: 100 objects detected
# 🔎 Frame 286: 100 objects detected
# 🔎 Frame 287: 100 objects detected
# 🔎 Frame 288: 100 objects detected
# 🔎 Frame 289: 100 objects detected
# 🔎 Frame 290: 100 objects detected
# 🔎 Frame 291: 100 objects detected
# 🔎 Frame 292: 100 objects detected
# 🔎 Frame 293: 100 objects detected
# 🔎 Frame 294: 100 objects detected
# 🔎 Frame 295: 100 objects detected
# 🔎 Frame 296: 100 objects detected
# 🔎 Frame 297: 100 objects detected
# 🔎 Frame 298: 100 objects detected
# 🔎 Frame 299: 100 objects detected
# 🔎 Frame 300: 100 objects detected
# 🔎 Frame 301: 100 objects detected
# 🔎 Frame 302: 100 objects detected
# 🔎 Frame 303: 100 objects detected
# 🔎 Frame 304: 100 objects detected
# 🔎 Frame 305: 100 objects detected
# 🔎 Frame 306: 100 objects detected
# 🔎 Frame 307: 100 objects detected
# 🔎 Frame 308: 100 objects detected
# 🔎 Frame 309: 100 objects detected
# 🔎 Frame 310: 100 objects detected
# 🔎 Frame 311: 100 objects detected
# 🔎 Frame 312: 100 objects detected
# 🔎 Frame 313: 100 objects detected
# 🔎 Frame 314: 100 objects detected
# 🔎 Frame 315: 100 objects detected
# 🔎 Frame 316: 100 objects detected
# 🔎 Frame 317: 100 objects detected
# 🔎 Frame 318: 100 objects detected
# 🔎 Frame 319: 100 objects detected
# 🔎 Frame 320: 100 objects detected
# 🔎 Frame 321: 100 objects detected
# 🔎 Frame 322: 100 objects detected
# 🔎 Frame 323: 100 objects detected
# 🔎 Frame 324: 100 objects detected
# 🔎 Frame 325: 100 objects detected
# 🔎 Frame 326: 100 objects detected
# 🔎 Frame 327: 100 objects detected
# 🔎 Frame 328: 100 objects detected
# 🔎 Frame 329: 100 objects detected
# 🔎 Frame 330: 100 objects detected
# 🔎 Frame 331: 100 objects detected
# 🔎 Frame 332: 100 objects detected
# 🔎 Frame 333: 100 objects detected
# 🔎 Frame 334: 100 objects detected
# 🔎 Frame 335: 100 objects detected
# 🔎 Frame 336: 100 objects detected
# 🔎 Frame 337: 100 objects detected
# 🔎 Frame 338: 100 objects detected
# 🔎 Frame 339: 100 objects detected
# 🔎 Frame 340: 99 objects detected
# 🔎 Frame 341: 98 objects detected
# 🔎 Frame 342: 100 objects detected
# 🔎 Frame 343: 98 objects detected
# 🔎 Frame 344: 97 objects detected
# 🔎 Frame 345: 98 objects detected
# 🔎 Frame 346: 98 objects detected
# 🔎 Frame 347: 99 objects detected
# 🔎 Frame 348: 97 objects detected
# 🔎 Frame 349: 98 objects detected
# 🔎 Frame 350: 100 objects detected
# 🔎 Frame 351: 100 objects detected
# 🔎 Frame 352: 100 objects detected
# 🔎 Frame 353: 100 objects detected
# 🔎 Frame 354: 100 objects detected
# 🔎 Frame 355: 100 objects detected
# 🔎 Frame 356: 100 objects detected
# 🔎 Frame 357: 100 objects detected
# 🔎 Frame 358: 100 objects detected
# 🔎 Frame 359: 100 objects detected
# 🔎 Frame 360: 100 objects detected
# 🔎 Frame 361: 98 objects detected
# 🔎 Frame 362: 100 objects detected
# 🔎 Frame 363: 100 objects detected
# 🔎 Frame 364: 100 objects detected
# 🔎 Frame 365: 100 objects detected
# 🔎 Frame 366: 99 objects detected
# 🔎 Frame 367: 100 objects detected
# 🔎 Frame 368: 100 objects detected
# 🔎 Frame 369: 100 objects detected
# 🔎 Frame 370: 100 objects detected
# 🔎 Frame 371: 100 objects detected
# 🔎 Frame 372: 100 objects detected
# 🔎 Frame 373: 100 objects detected
# 🔎 Frame 374: 100 objects detected
# 🔎 Frame 375: 100 objects detected
# 🔎 Frame 376: 100 objects detected
# 🔎 Frame 377: 100 objects detected
# 🔎 Frame 378: 100 objects detected
# 🔎 Frame 379: 100 objects detected
# 🔎 Frame 380: 100 objects detected
# 🔎 Frame 381: 100 objects detected
# 🔎 Frame 382: 100 objects detected
# 🔎 Frame 383: 100 objects detected
# 🔎 Frame 384: 100 objects detected
# 🔎 Frame 385: 100 objects detected
# 🔎 Frame 386: 100 objects detected
# 🔎 Frame 387: 100 objects detected
# 🔎 Frame 388: 100 objects detected
# 🔎 Frame 389: 100 objects detected
# 🔎 Frame 390: 100 objects detected
# 🔎 Frame 391: 100 objects detected
# 🔎 Frame 392: 100 objects detected
# 🔎 Frame 393: 100 objects detected
# 🔎 Frame 394: 100 objects detected
# 🔎 Frame 395: 100 objects detected
# 🔎 Frame 396: 100 objects detected
# 🔎 Frame 397: 100 objects detected
# 🔎 Frame 398: 100 objects detected
# 🔎 Frame 399: 100 objects detected
# 🔎 Frame 400: 100 objects detected
# 🔎 Frame 401: 100 objects detected
# 🔎 Frame 402: 100 objects detected
# 🔎 Frame 403: 99 objects detected
# 🔎 Frame 404: 100 objects detected
# 🔎 Frame 405: 100 objects detected
# 🔎 Frame 406: 96 objects detected
# 🔎 Frame 407: 100 objects detected
# 🔎 Frame 408: 100 objects detected
# 🔎 Frame 409: 100 objects detected
# 🔎 Frame 410: 100 objects detected
# 🔎 Frame 411: 100 objects detected
# 🔎 Frame 412: 100 objects detected
# 🔎 Frame 413: 100 objects detected
# 🔎 Frame 414: 100 objects detected
# 🔎 Frame 415: 100 objects detected
# 🔎 Frame 416: 100 objects detected
# 🔎 Frame 417: 100 objects detected
# 🔎 Frame 418: 100 objects detected
# 🔎 Frame 419: 100 objects detected
# 🔎 Frame 420: 100 objects detected
# 🔎 Frame 421: 100 objects detected
# 🔎 Frame 422: 100 objects detected
# 🔎 Frame 423: 100 objects detected
# 🔎 Frame 424: 100 objects detected
# 🔎 Frame 425: 100 objects detected
# 🔎 Frame 426: 100 objects detected
# 🔎 Frame 427: 100 objects detected
# 🔎 Frame 428: 100 objects detected
# 🔎 Frame 429: 100 objects detected
# 🔎 Frame 430: 100 objects detected
# 🔎 Frame 431: 100 objects detected
# 🔎 Frame 432: 100 objects detected
# 🔎 Frame 433: 100 objects detected
# 🔎 Frame 434: 100 objects detected
# 🔎 Frame 435: 100 objects detected
# 🔎 Frame 436: 100 objects detected
# 🔎 Frame 437: 98 objects detected
# 🔎 Frame 438: 100 objects detected
# 🔎 Frame 439: 95 objects detected
# 🔎 Frame 440: 100 objects detected
# 🔎 Frame 441: 100 objects detected
# 🔎 Frame 442: 100 objects detected
# 🔎 Frame 443: 100 objects detected
# 🔎 Frame 444: 100 objects detected
# 🔎 Frame 445: 100 objects detected
# 🔎 Frame 446: 99 objects detected
# 🔎 Frame 447: 100 objects detected
# 🔎 Frame 448: 100 objects detected
# 🔎 Frame 449: 100 objects detected
# 🔎 Frame 450: 100 objects detected
# 🔎 Frame 451: 100 objects detected
# 🔎 Frame 452: 100 objects detected
# 🔎 Frame 453: 100 objects detected
# 🔎 Frame 454: 100 objects detected
# 🔎 Frame 455: 87 objects detected
# 🔎 Frame 456: 97 objects detected
# 🔎 Frame 457: 87 objects detected
# 🔎 Frame 458: 90 objects detected
# 🔎 Frame 459: 98 objects detected
# 🔎 Frame 460: 100 objects detected
# 🔎 Frame 461: 100 objects detected
# 🔎 Frame 462: 100 objects detected
# 🔎 Frame 463: 100 objects detected
# 🔎 Frame 464: 100 objects detected
# 🔎 Frame 465: 100 objects detected
# 🔎 Frame 466: 86 objects detected
# 🔎 Frame 467: 93 objects detected
# 🔎 Frame 468: 90 objects detected
# 🔎 Frame 469: 99 objects detected
# 🔎 Frame 470: 98 objects detected
# 🔎 Frame 471: 75 objects detected
# 🔎 Frame 472: 92 objects detected
# 🔎 Frame 473: 84 objects detected
# 🔎 Frame 474: 96 objects detected
# 🔎 Frame 475: 95 objects detected
# 🔎 Frame 476: 95 objects detected
# 🔎 Frame 477: 97 objects detected
# 🔎 Frame 478: 99 objects detected
# 🔎 Frame 479: 100 objects detected
# 🔎 Frame 480: 91 objects detected
# 🔎 Frame 481: 100 objects detected
# 🔎 Frame 482: 98 objects detected
# 🔎 Frame 483: 96 objects detected
# 🔎 Frame 484: 84 objects detected
# 🔎 Frame 485: 86 objects detected
# 🔎 Frame 486: 87 objects detected
# 🔎 Frame 487: 74 objects detected
# 🔎 Frame 488: 79 objects detected
# 🔎 Frame 489: 84 objects detected
# 🔎 Frame 490: 75 objects detected
# 🔎 Frame 491: 75 objects detected
# 🔎 Frame 492: 82 objects detected
# 🔎 Frame 493: 77 objects detected
# 🔎 Frame 494: 77 objects detected
# 🔎 Frame 495: 78 objects detected
# 🔎 Frame 496: 77 objects detected
# 🔎 Frame 497: 78 objects detected
# 🔎 Frame 498: 79 objects detected
# 🔎 Frame 499: 80 objects detected
# 🔎 Frame 500: 76 objects detected
# 🔎 Frame 501: 79 objects detected
# 🔎 Frame 502: 76 objects detected
# 🔎 Frame 503: 87 objects detected
# 🔎 Frame 504: 85 objects detected
# 🔎 Frame 505: 87 objects detected
# 🔎 Frame 506: 87 objects detected
# 🔎 Frame 507: 82 objects detected
# 🔎 Frame 508: 82 objects detected
# 🔎 Frame 509: 86 objects detected
# 🔎 Frame 510: 88 objects detected
# 🔎 Frame 511: 84 objects detected
# 🔎 Frame 512: 100 objects detected
# 🔎 Frame 513: 100 objects detected
# 🔎 Frame 514: 93 objects detected
# 🔎 Frame 515: 97 objects detected
# 🔎 Frame 516: 93 objects detected
# 🔎 Frame 517: 97 objects detected
# 🔎 Frame 518: 91 objects detected
# 🔎 Frame 519: 87 objects detected
# 🔎 Frame 520: 100 objects detected
# 🔎 Frame 521: 98 objects detected
# 🔎 Frame 522: 100 objects detected
# 🔎 Frame 523: 100 objects detected
# 🔎 Frame 524: 100 objects detected
# 🔎 Frame 525: 100 objects detected
# 🔎 Frame 526: 100 objects detected
# 🔎 Frame 527: 100 objects detected
# 🔎 Frame 528: 100 objects detected
# 🔎 Frame 529: 100 objects detected
# 🔎 Frame 530: 100 objects detected
# 🔎 Frame 531: 100 objects detected
# 🔎 Frame 532: 99 objects detected
# 🔎 Frame 533: 99 objects detected
# 🔎 Frame 534: 100 objects detected
# 🔎 Frame 535: 100 objects detected
# 🔎 Frame 536: 100 objects detected
# 🔎 Frame 537: 92 objects detected
# 🔎 Frame 538: 100 objects detected
# 🔎 Frame 539: 100 objects detected
# 🔎 Frame 540: 100 objects detected
# 🔎 Frame 541: 100 objects detected
# 🔎 Frame 542: 100 objects detected
# 🔎 Frame 543: 100 objects detected
# 🔎 Frame 544: 100 objects detected
# 🔎 Frame 545: 100 objects detected
# 🔎 Frame 546: 95 objects detected
# 🔎 Frame 547: 89 objects detected
# 🔎 Frame 548: 100 objects detected
# 🔎 Frame 549: 87 objects detected
# 🔎 Frame 550: 87 objects detected
# 🔎 Frame 551: 85 objects detected
# 🔎 Frame 552: 83 objects detected
# 🔎 Frame 553: 85 objects detected
# 🔎 Frame 554: 82 objects detected
# 🔎 Frame 555: 85 objects detected
# 🔎 Frame 556: 86 objects detected
# 🔎 Frame 557: 85 objects detected
# 🔎 Frame 558: 87 objects detected
# 🔎 Frame 559: 87 objects detected
# 🔎 Frame 560: 88 objects detected
# 🔎 Frame 561: 87 objects detected
# 🔎 Frame 562: 86 objects detected
# 🔎 Frame 563: 85 objects detected
# 🔎 Frame 564: 87 objects detected
# 🔎 Frame 565: 88 objects detected
# 🔎 Frame 566: 85 objects detected
# 🔎 Frame 567: 86 objects detected
# 🔎 Frame 568: 86 objects detected
# 🔎 Frame 569: 88 objects detected
# 🔎 Frame 570: 85 objects detected
# 🔎 Frame 571: 86 objects detected
# 🔎 Frame 572: 87 objects detected
# 🔎 Frame 573: 87 objects detected
# 🔎 Frame 574: 87 objects detected
# 🔎 Frame 575: 89 objects detected
# 🔎 Frame 576: 88 objects detected
# 🔎 Frame 577: 88 objects detected
# 🔎 Frame 578: 88 objects detected
# 🔎 Frame 579: 86 objects detected
# 🔎 Frame 580: 88 objects detected
# 🔎 Frame 581: 89 objects detected
# 🔎 Frame 582: 86 objects detected
# 🔎 Frame 583: 87 objects detected
# 🔎 Frame 584: 86 objects detected
# 🔎 Frame 585: 93 objects detected
# 🔎 Frame 586: 100 objects detected
# 🔎 Frame 587: 100 objects detected
# 🔎 Frame 588: 100 objects detected
# 🔎 Frame 589: 89 objects detected
# 🔎 Frame 590: 100 objects detected
# 🔎 Frame 591: 100 objects detected
# 🔎 Frame 592: 100 objects detected
# 🔎 Frame 593: 100 objects detected
# 🔎 Frame 594: 94 objects detected
# 🔎 Frame 595: 97 objects detected
# 🔎 Frame 596: 100 objects detected
# 🔎 Frame 597: 100 objects detected
# 🔎 Frame 598: 100 objects detected
# 🔎 Frame 599: 100 objects detected
# 🔎 Frame 600: 100 objects detected
# 🔎 Frame 601: 100 objects detected
# 🔎 Frame 602: 100 objects detected
# 🔎 Frame 603: 100 objects detected
# 🔎 Frame 604: 100 objects detected
# 🔎 Frame 605: 100 objects detected
# 🔎 Frame 606: 100 objects detected
# 🔎 Frame 607: 100 objects detected
# 🔎 Frame 608: 100 objects detected
# 🔎 Frame 609: 100 objects detected
# 🔎 Frame 610: 100 objects detected
# 🔎 Frame 611: 100 objects detected
# 🔎 Frame 612: 100 objects detected
# 🔎 Frame 613: 100 objects detected
# 🔎 Frame 614: 100 objects detected
# 🔎 Frame 615: 100 objects detected
# 🔎 Frame 616: 100 objects detected
# 🔎 Frame 617: 100 objects detected
# 🔎 Frame 618: 100 objects detected
# 🔎 Frame 619: 100 objects detected
# 🔎 Frame 620: 100 objects detected
# 🔎 Frame 621: 100 objects detected
# 🔎 Frame 622: 100 objects detected
# 🔎 Frame 623: 100 objects detected
# 🔎 Frame 624: 100 objects detected
# 🔎 Frame 625: 100 objects detected
# 🔎 Frame 626: 100 objects detected
# 🔎 Frame 627: 100 objects detected
# 🔎 Frame 628: 100 objects detected
# 🔎 Frame 629: 100 objects detected
# 🔎 Frame 630: 100 objects detected
# 🔎 Frame 631: 100 objects detected
# 🔎 Frame 632: 100 objects detected
# 🔎 Frame 633: 100 objects detected
# 🔎 Frame 634: 100 objects detected
# 🔎 Frame 635: 100 objects detected
# 🔎 Frame 636: 100 objects detected
# 🔎 Frame 637: 100 objects detected
# 🔎 Frame 638: 100 objects detected
# 🔎 Frame 639: 100 objects detected
# 🔎 Frame 640: 100 objects detected
# 🔎 Frame 641: 100 objects detected
# 🔎 Frame 642: 100 objects detected
# 🔎 Frame 643: 100 objects detected
# 🔎 Frame 644: 100 objects detected
# 🔎 Frame 645: 100 objects detected
# 🔎 Frame 646: 100 objects detected
# 🔎 Frame 647: 100 objects detected
# 🔎 Frame 648: 100 objects detected
# 🔎 Frame 649: 100 objects detected
# 🔎 Frame 650: 100 objects detected
# 🔎 Frame 651: 100 objects detected
# 🔎 Frame 652: 100 objects detected
# 🔎 Frame 653: 100 objects detected
# 🔎 Frame 654: 100 objects detected
# 🔎 Frame 655: 100 objects detected
# 🔎 Frame 656: 100 objects detected
# 🔎 Frame 657: 100 objects detected
# 🔎 Frame 658: 100 objects detected
# 🔎 Frame 659: 100 objects detected
# 🔎 Frame 660: 100 objects detected
# 🔎 Frame 661: 100 objects detected
# 🔎 Frame 662: 100 objects detected
# 🔎 Frame 663: 100 objects detected
# 🔎 Frame 664: 100 objects detected
# 🔎 Frame 665: 100 objects detected
# 🔎 Frame 666: 100 objects detected
# 🔎 Frame 667: 100 objects detected
# 🔎 Frame 668: 100 objects detected
# 🔎 Frame 669: 100 objects detected
# 🔎 Frame 670: 100 objects detected
# 🔎 Frame 671: 100 objects detected
# 🔎 Frame 672: 100 objects detected
# 🔎 Frame 673: 100 objects detected
# 🔎 Frame 674: 100 objects detected
# 🔎 Frame 675: 100 objects detected
# 🔎 Frame 676: 100 objects detected
# 🔎 Frame 677: 100 objects detected
# 🔎 Frame 678: 100 objects detected
# 🔎 Frame 679: 100 objects detected
# 🔎 Frame 680: 100 objects detected
# 🔎 Frame 681: 100 objects detected
# 🔎 Frame 682: 100 objects detected
# 🔎 Frame 683: 100 objects detected
# 🔎 Frame 684: 100 objects detected
# 🔎 Frame 685: 100 objects detected
# 🔎 Frame 686: 100 objects detected
# 🔎 Frame 687: 100 objects detected
# 🔎 Frame 688: 100 objects detected
# 🔎 Frame 689: 100 objects detected
# 🔎 Frame 690: 100 objects detected
# 🔎 Frame 691: 100 objects detected
# 🔎 Frame 692: 100 objects detected
# 🔎 Frame 693: 100 objects detected
# 🔎 Frame 694: 100 objects detected
# 🔎 Frame 695: 100 objects detected
# 🔎 Frame 696: 100 objects detected
# 🔎 Frame 697: 100 objects detected
# 🔎 Frame 698: 100 objects detected
# 🔎 Frame 699: 100 objects detected
# 🔎 Frame 700: 100 objects detected
# 🔎 Frame 701: 100 objects detected
# 🔎 Frame 702: 100 objects detected
# 🔎 Frame 703: 100 objects detected
# 🔎 Frame 704: 100 objects detected
# 🔎 Frame 705: 100 objects detected
# 🔎 Frame 706: 100 objects detected
# 🔎 Frame 707: 100 objects detected
# 🔎 Frame 708: 100 objects detected
# 🔎 Frame 709: 100 objects detected
# 🔎 Frame 710: 100 objects detected
# 🔎 Frame 711: 100 objects detected
# 🔎 Frame 712: 100 objects detected
# 🔎 Frame 713: 100 objects detected
# 🔎 Frame 714: 100 objects detected
# 🔎 Frame 715: 100 objects detected
# 🔎 Frame 716: 100 objects detected
# 🔎 Frame 717: 100 objects detected
# 🔎 Frame 718: 100 objects detected
# 🔎 Frame 719: 100 objects detected
# 🔎 Frame 720: 100 objects detected
# 🔎 Frame 721: 100 objects detected
# 🔎 Frame 722: 100 objects detected
# 🔎 Frame 723: 100 objects detected
# 🔎 Frame 724: 100 objects detected
# 🔎 Frame 725: 100 objects detected
# 🔎 Frame 726: 100 objects detected
# 🔎 Frame 727: 100 objects detected
# 🔎 Frame 728: 100 objects detected
# 🔎 Frame 729: 100 objects detected
# 🔎 Frame 730: 100 objects detected
# 🔎 Frame 731: 100 objects detected
# 🔎 Frame 732: 100 objects detected
# 🔎 Frame 733: 100 objects detected
# 🔎 Frame 734: 100 objects detected
# 🔎 Frame 735: 100 objects detected
# 🔎 Frame 736: 100 objects detected
# 🔎 Frame 737: 100 objects detected
# 🔎 Frame 738: 100 objects detected
# 🔎 Frame 739: 100 objects detected
# 🔎 Frame 740: 100 objects detected
# 🔎 Frame 741: 100 objects detected
# 🔎 Frame 742: 100 objects detected
# 🔎 Frame 743: 100 objects detected
# 🔎 Frame 744: 100 objects detected
# 🔎 Frame 745: 100 objects detected
# 🔎 Frame 746: 100 objects detected
# 🔎 Frame 747: 100 objects detected
# 🔎 Frame 748: 100 objects detected
# 🔎 Frame 749: 100 objects detected
# 🔎 Frame 750: 100 objects detected
# 🔎 Frame 751: 100 objects detected
# 🔎 Frame 752: 100 objects detected
# 🔎 Frame 753: 100 objects detected
# 🔎 Frame 754: 100 objects detected
# 🔎 Frame 755: 100 objects detected
# 🔎 Frame 756: 100 objects detected
# 🔎 Frame 757: 100 objects detected
# 🔎 Frame 758: 100 objects detected
# 🔎 Frame 759: 100 objects detected
# 🔎 Frame 760: 100 objects detected
# 🔎 Frame 761: 100 objects detected
# 🔎 Frame 762: 100 objects detected
# 🔎 Frame 763: 100 objects detected
# 🔎 Frame 764: 100 objects detected
# 🔎 Frame 765: 100 objects detected
# 🔎 Frame 766: 100 objects detected
# 🔎 Frame 767: 100 objects detected
# 🔎 Frame 768: 100 objects detected
# 🔎 Frame 769: 100 objects detected
# 🔎 Frame 770: 100 objects detected
# 🔎 Frame 771: 100 objects detected
# 🔎 Frame 772: 100 objects detected
# 🔎 Frame 773: 100 objects detected
# 🔎 Frame 774: 100 objects detected
# 🔎 Frame 775: 95 objects detected
# 🔎 Frame 776: 94 objects detected
# 🔎 Frame 777: 76 objects detected
# 🔎 Frame 778: 73 objects detected
# 🔎 Frame 779: 76 objects detected
# 🔎 Frame 780: 81 objects detected
# 🔎 Frame 781: 79 objects detected
# 🔎 Frame 782: 81 objects detected
# 🔎 Frame 783: 81 objects detected
# 🔎 Frame 784: 70 objects detected
# 🔎 Frame 785: 81 objects detected
# 🔎 Frame 786: 76 objects detected
# 🔎 Frame 787: 81 objects detected
# 🔎 Frame 788: 83 objects detected
# 🔎 Frame 789: 82 objects detected
# 🔎 Frame 790: 83 objects detected
# 🔎 Frame 791: 81 objects detected
# 🔎 Frame 792: 84 objects detected
# 🔎 Frame 793: 83 objects detected
# 🔎 Frame 794: 81 objects detected
# 🔎 Frame 795: 83 objects detected
# 🔎 Frame 796: 78 objects detected
# 🔎 Frame 797: 76 objects detected
# 🔎 Frame 798: 79 objects detected
# 🔎 Frame 799: 87 objects detected
# 🔎 Frame 800: 85 objects detected
# 🔎 Frame 801: 85 objects detected
# 🔎 Frame 802: 86 objects detected
# 🔎 Frame 803: 84 objects detected
# 🔎 Frame 804: 87 objects detected
# 🔎 Frame 805: 84 objects detected
# 🔎 Frame 806: 81 objects detected
# 🔎 Frame 807: 85 objects detected
# 🔎 Frame 808: 82 objects detected
# 🔎 Frame 809: 84 objects detected
# 🔎 Frame 810: 88 objects detected
# 🔎 Frame 811: 88 objects detected
# 🔎 Frame 812: 85 objects detected
# 🔎 Frame 813: 87 objects detected
# 🔎 Frame 814: 86 objects detected
# 🔎 Frame 815: 86 objects detected
# 🔎 Frame 816: 84 objects detected
# 🔎 Frame 817: 85 objects detected
# 🔎 Frame 818: 85 objects detected
# 🔎 Frame 819: 85 objects detected
# 🔎 Frame 820: 85 objects detected
# 🔎 Frame 821: 70 objects detected
# 🔎 Frame 822: 73 objects detected
# 🔎 Frame 823: 71 objects detected
# 🔎 Frame 824: 69 objects detected
# 🔎 Frame 825: 70 objects detected
# 🔎 Frame 826: 71 objects detected
# 🔎 Frame 827: 69 objects detected
# 🔎 Frame 828: 67 objects detected
# 🔎 Frame 829: 69 objects detected
# 🔎 Frame 830: 72 objects detected
# 🔎 Frame 831: 75 objects detected
# 🔎 Frame 832: 76 objects detected
# 🔎 Frame 833: 72 objects detected
# 🔎 Frame 834: 74 objects detected
# 🔎 Frame 835: 75 objects detected
# 🔎 Frame 836: 73 objects detected
# 🔎 Frame 837: 74 objects detected
# 🔎 Frame 838: 76 objects detected
# 🔎 Frame 839: 69 objects detected
# 🔎 Frame 840: 72 objects detected
# 🔎 Frame 841: 68 objects detected
# 🔎 Frame 842: 70 objects detected
# 🔎 Frame 843: 72 objects detected
# 🔎 Frame 844: 72 objects detected
# 🔎 Frame 845: 69 objects detected
# 🔎 Frame 846: 70 objects detected
# 🔎 Frame 847: 71 objects detected
# 🔎 Frame 848: 70 objects detected
# 🔎 Frame 849: 70 objects detected
# 🔎 Frame 850: 69 objects detected
# 🔎 Frame 851: 69 objects detected
# 🔎 Frame 852: 69 objects detected
# 🔎 Frame 853: 69 objects detected
# 🔎 Frame 854: 69 objects detected
# 🔎 Frame 855: 69 objects detected
# 🔎 Frame 856: 69 objects detected
# 🔎 Frame 857: 69 objects detected
# 🔎 Frame 858: 69 objects detected
# 🔎 Frame 859: 69 objects detected
# 🔎 Frame 860: 69 objects detected
# 🔎 Frame 861: 69 objects detected
# 🔎 Frame 862: 69 objects detected
# 🔎 Frame 863: 69 objects detected
# 🔎 Frame 864: 69 objects detected
# 🔎 Frame 865: 70 objects detected
# 🔎 Frame 866: 69 objects detected
# 🔎 Frame 867: 69 objects detected
# 🔎 Frame 868: 69 objects detected
# 🔎 Frame 869: 69 objects detected
# 🔎 Frame 870: 69 objects detected
# 🔎 Frame 871: 69 objects detected
# 🔎 Frame 872: 69 objects detected
# 🔎 Frame 873: 70 objects detected
# 🔎 Frame 874: 69 objects detected
# 🔎 Frame 875: 69 objects detected
# 🔎 Frame 876: 69 objects detected
# 🔎 Frame 877: 70 objects detected
# 🔎 Frame 878: 69 objects detected
# 🔎 Frame 879: 69 objects detected
# 🔎 Frame 880: 69 objects detected
# 🔎 Frame 881: 69 objects detected
# 🔎 Frame 882: 69 objects detected
# 🔎 Frame 883: 69 objects detected
# 🔎 Frame 884: 69 objects detected
# 🔎 Frame 885: 70 objects detected
# 🔎 Frame 886: 69 objects detected
# 🔎 Frame 887: 68 objects detected
# 🔎 Frame 888: 69 objects detected
# 🔎 Frame 889: 69 objects detected
# 🔎 Frame 890: 69 objects detected
# 🔎 Frame 891: 68 objects detected
# 🔎 Frame 892: 69 objects detected
# 🔎 Frame 893: 68 objects detected
# 🔎 Frame 894: 68 objects detected
# 🔎 Frame 895: 68 objects detected
# 🔎 Frame 896: 68 objects detected
# 🔎 Frame 897: 69 objects detected
# 🔎 Frame 898: 69 objects detected
# 🔎 Frame 899: 69 objects detected
# 🔎 Frame 900: 72 objects detected
# 🔎 Frame 901: 71 objects detected
# 🔎 Frame 902: 69 objects detected
# 🔎 Frame 903: 75 objects detected
# 🔎 Frame 904: 71 objects detected
# 🔎 Frame 905: 69 objects detected
# 🔎 Frame 906: 72 objects detected
# 🔎 Frame 907: 75 objects detected
# 🔎 Frame 908: 77 objects detected
# 🔎 Frame 909: 75 objects detected
# 🔎 Frame 910: 78 objects detected
# 🔎 Frame 911: 77 objects detected
# 🔎 Frame 912: 76 objects detected
# 🔎 Frame 913: 76 objects detected
# 🔎 Frame 914: 79 objects detected
# 🔎 Frame 915: 79 objects detected
# 🔎 Frame 916: 78 objects detected
# 🔎 Frame 917: 77 objects detected
# 🔎 Frame 918: 77 objects detected
# 🔎 Frame 919: 78 objects detected
# 🔎 Frame 920: 77 objects detected
# 🔎 Frame 921: 76 objects detected
# 🔎 Frame 922: 76 objects detected
# 🔎 Frame 923: 76 objects detected
# 🔎 Frame 924: 76 objects detected
# 🔎 Frame 925: 75 objects detected
# 🔎 Frame 926: 76 objects detected
# 🔎 Frame 927: 76 objects detected
# 🔎 Frame 928: 76 objects detected
# 🔎 Frame 929: 77 objects detected
# 🔎 Frame 930: 77 objects detected
# 🔎 Frame 931: 76 objects detected
# 🔎 Frame 932: 77 objects detected
# 🔎 Frame 933: 76 objects detected
# 🔎 Frame 934: 77 objects detected
# 🔎 Frame 935: 76 objects detected
# 🔎 Frame 936: 77 objects detected
# 🔎 Frame 937: 77 objects detected
# 🔎 Frame 938: 77 objects detected
# 🔎 Frame 939: 76 objects detected
# 🔎 Frame 940: 77 objects detected
# 🔎 Frame 941: 78 objects detected
# 🔎 Frame 942: 77 objects detected
# 🔎 Frame 943: 76 objects detected
# 🔎 Frame 944: 76 objects detected
# 🔎 Frame 945: 64 objects detected
# 🔎 Frame 946: 59 objects detected
# 🔎 Frame 947: 63 objects detected
# 🔎 Frame 948: 73 objects detected
# 🔎 Frame 949: 69 objects detected
# 🔎 Frame 950: 86 objects detected
# 🔎 Frame 951: 76 objects detected
# 🔎 Frame 952: 90 objects detected
# 🔎 Frame 953: 85 objects detected
# 🔎 Frame 954: 77 objects detected
# 🔎 Frame 955: 80 objects detected
# 🔎 Frame 956: 80 objects detected
# 🔎 Frame 957: 83 objects detected
# 🔎 Frame 958: 83 objects detected
# 🔎 Frame 959: 81 objects detected
# 🔎 Frame 960: 82 objects detected
# 🔎 Frame 961: 81 objects detected
# 🔎 Frame 962: 80 objects detected
# 🔎 Frame 963: 84 objects detected
# 🔎 Frame 964: 82 objects detected
# 🔎 Frame 965: 84 objects detected
# 🔎 Frame 966: 83 objects detected
# 🔎 Frame 967: 84 objects detected
# 🔎 Frame 968: 78 objects detected
# 🔎 Frame 969: 73 objects detected
# 🔎 Frame 970: 79 objects detected
# 🔎 Frame 971: 91 objects detected
# 🔎 Frame 972: 94 objects detected
# 🔎 Frame 973: 87 objects detected
# 🔎 Frame 974: 75 objects detected
# 🔎 Frame 975: 84 objects detected
# 🔎 Frame 976: 92 objects detected
# 🔎 Frame 977: 98 objects detected
# 🔎 Frame 978: 82 objects detected
# 🔎 Frame 979: 79 objects detected
# 🔎 Frame 980: 80 objects detected
# 🔎 Frame 981: 81 objects detected
# 🔎 Frame 982: 78 objects detected
# 🔎 Frame 983: 79 objects detected
# 🔎 Frame 984: 80 objects detected
# 🔎 Frame 985: 80 objects detected
# 🔎 Frame 986: 78 objects detected
# 🔎 Frame 987: 78 objects detected
# 🔎 Frame 988: 81 objects detected
# 🔎 Frame 989: 76 objects detected
# 🔎 Frame 990: 80 objects detected
# 🔎 Frame 991: 84 objects detected
# 🔎 Frame 992: 83 objects detected
# 🔎 Frame 993: 79 objects detected
# 🔎 Frame 994: 87 objects detected
# 🔎 Frame 995: 83 objects detected
# 🔎 Frame 996: 84 objects detected
# 🔎 Frame 997: 78 objects detected
# 🔎 Frame 998: 76 objects detected
# 🔎 Frame 999: 75 objects detected
# 🔎 Frame 1000: 73 objects detected
# 🔎 Frame 1001: 73 objects detected
# 🔎 Frame 1002: 73 objects detected
# 🔎 Frame 1003: 73 objects detected
# 🔎 Frame 1004: 73 objects detected
# 🔎 Frame 1005: 72 objects detected
# 🔎 Frame 1006: 75 objects detected
# 🔎 Frame 1007: 74 objects detected
# 🔎 Frame 1008: 74 objects detected
# 🔎 Frame 1009: 74 objects detected
# 🔎 Frame 1010: 76 objects detected
# 🔎 Frame 1011: 76 objects detected
# 🔎 Frame 1012: 76 objects detected
# 🔎 Frame 1013: 74 objects detected
# 🔎 Frame 1014: 74 objects detected
# 🔎 Frame 1015: 75 objects detected
# 🔎 Frame 1016: 73 objects detected
# 🔎 Frame 1017: 74 objects detected
# ✅ Processed video saved: output_videos/video1_detected.mp4 with 92944 detections.
